# %%
import os
import tweepy 
import configparser

# %%
consumer_key='uxIhmpOUkeeMYrRhVstivIkne'
consumer_secret='bQ6w3mkKHfo0fNISOJVZpJxDfFv5VLfgdhsAkhRW17689Skqsd'
access_token='1366592995944898562-XGRWIlU6JaFUpMpVxlIogug7g1CmUE'
access_token_secret='3QXzoKiNCwvNk94cn7uM805Degfa7P6qYGFllMP8RGgjw'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
search_words="#covid"
date_since="2021-04-20"

# %%
tweets=tweepy.Cursor(api.search,
                q=search_words,
                lang="en",
                since=date_since).items(100)

# %%
tweets

# %%
tweet_details=[[tweet.geo,tweet.text,tweet.user.screen_name,tweet.user.location]for tweet in tweets]

# %%
import pandas as pd

# %%
tweet_df=pd.DataFrame(data=tweet_details, columns=['geo','text','user',"location"])

# %%
pd.set_option('max_colwidth', 800)
tweet_df.head(50)
# Out:
#      geo  \
# 0   None
# 1   None
# 2   None
# 3   None
# 4   None
# 5   None
# 6   None
# 7   None
# 8   None
# 9   None
# 10  None
# 11  None
# 12  None
# 13  None
# 14  None
# 15  None
# 16  None
# 17  None
# 18  None
# 19  None
#
#                                                                                                                                                   text  \
# 0   RT @arunbothra: We are flooded with requests for #Plasma. Pl come forward to donate &amp; save lives of fellow countrymen.\n\nKindly click the li…
# 1         @annita_mcveigh #BBCYourQuestions One only needs to see media from #India to understand why #Covid is rising. Peopl… https://t.co/pUyle1InCG
# 2    RT @SamKhanpti1: #COVID positivity rate in🇵🇰 based on cities during the last 24 hours.\n\nMardan:34.27%\nMultan:33.55%\nPeshawar:26.06%\nBahawal…
# ...

# %%
tweet_df.user.value_counts()
# Out:
# BearTheCat2        2
# plasmabot2         2
# MintuLoveIndia     2
# Anirban_Atarthy    2
# Samir78096014      1
#                   ..
# kaapiNkindle       1
# PChitra6           1
# amardasbhalla      1
# Researchnewscc     1
# ILegalThailand     1
# Name: user, Length: 96, dtype: int64

# %%
tweet_df.location.value_counts()
# Out:
#                                    28
# India                               6
# Mumbai, India                       4
# Earth                               3
# Kharagpur, India                    2
# Tangla, India                       2
# United States                       2
# Mumbai                              1
# Lagos, Nigeria                      1
# Maharashtra, India                  1
# Bengaluru, India                    1
# she/her (I don't fb)                1
# Karaikal                            1
# Chennai, India                      1
# Punjab                              1
# Confidential                        1
# 🇮🇳                                  1
# Southern California, U.S.           1
# Hyderabad,Hyd                       1
# Universe                            1
# South West England                  1
# she/her                             1
# Mars                                1
# Italy                               1
# Guwahati, India                     1
# ...

# %%
import re
def clean_tweets(text):
    text=re.sub("RT :","",text)
    text=re.sub("@[\w]*","",text)
    text=re.sub("https?://[A-Za-z0-9./]*","",text)
    text=re.sub("\n","",text)
    return text

# %%
tweet_df['text']=tweet_df['text'].apply(lambda x: clean_tweets(x))

# %%
tweet_df.head(20)
# Out:
#      geo  \
# 0   None
# 1   None
# 2   None
# 3   None
# 4   None
# 5   None
# 6   None
# 7   None
# 8   None
# 9   None
# 10  None
# 11  None
# 12  None
# 13  None
# 14  None
# 15  None
# 16  None
# 17  None
# 18  None
# 19  None
#
#                                                                                                                                text  \
# 0    We are flooded with requests for #Plasma. Pl come forward to donate &amp; save lives of fellow countrymen.Kindly click the li…
# 1                             #BBCYourQuestions One only needs to see media from #India to understand why #Covid is rising. Peopl…
# 2            #COVID positivity rate in🇵🇰 based on cities during the last 24 hours.Mardan:34.27%Multan:33.55%Peshawar:26.06%Bahawal…
# 3        #SOS #SOSNaviMumbai #Urgent I need ventilator for a senior citizen in Navi Mumbai please help 🙏🏼 HE'S 85 AND VERY CRITICA…
# ...

# %%
import csv

# %%
tweet_df.to_csv('tweets.csv')

# %%
import spacy 
import en_core_web_sm
nlp = spacy.load('en_core_web_sm')

# %%
tweet_df['text'].apply(lambda x: [print("\tText : {}, Entity : {}".format(ent.text, ent.label_)) if (not ent.text.startswith('#')) else "" for ent in nlp(x).ents ])
# Out:
# 	Text : Plasma, Entity : PERSON
# 	Text : One, Entity : CARDINAL
# 	Text : India, Entity : GPE
# 	Text : Covid, Entity : PERSON
# 	Text : 🇵, Entity : GPE
# 	Text : the last 24 hours, Entity : TIME
# 	Text : SOS, Entity : MONEY
# 	Text : Navi Mumbai, Entity : GPE
# 	Text : 85, Entity : CARDINAL
# 	Text : CRITICA, Entity : ORG
# 	Text : Remdevisir, Entity : PERSON
# 	Text : last 24 hours, Entity : TIME
# 	Text : 167457, Entity : DATE
# 	Text : 2898257, Entity : CARDINAL
# 	Text : Oxygen, Entity : ORG
# 	Text : UrgentPatient, Entity : ORG
# 	Text : 40Patient, Entity : CARDINAL
# 	Text : 75, Entity : CARDINAL
# 	Text : annual, Entity : DATE
# 	Text : PolicyConference, Entity : PRODUCT
# 	Text : AssamCovidUpdate, Entity : MONEY
# 	Text : 750, Entity : CARDINAL
# 	Text : 200, Entity : CARDINAL
# 	Text : ICU, Entity : ORG
# 	Text : Khanapara, Entity : GPE
# 	Text : India, Entity : GPE
# 	Text : PAN India, Entity : ORG
# 	Text : annual, Entity : DATE
# ...

# %%
tweet_df['entities']=tweet_df['text'].apply(lambda x: [(ent.text, ent.label_) if (not ent.text.startswith('#')) else "" for ent in nlp(x).ents ])

# %%
tweet_df.head(20)
# Out:
#      geo  \
# 0   None
# 1   None
# 2   None
# 3   None
# 4   None
# 5   None
# 6   None
# 7   None
# 8   None
# 9   None
# 10  None
# 11  None
# 12  None
# 13  None
# 14  None
# 15  None
# 16  None
# 17  None
# 18  None
# 19  None
#
#                                                                                                                                text  \
# 0    We are flooded with requests for #Plasma. Pl come forward to donate &amp; save lives of fellow countrymen.Kindly click the li…
# 1                             #BBCYourQuestions One only needs to see media from #India to understand why #Covid is rising. Peopl…
# 2            #COVID positivity rate in🇵🇰 based on cities during the last 24 hours.Mardan:34.27%Multan:33.55%Peshawar:26.06%Bahawal…
# 3        #SOS #SOSNaviMumbai #Urgent I need ventilator for a senior citizen in Navi Mumbai please help 🙏🏼 HE'S 85 AND VERY CRITICA…
# ...

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\aruny\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
sid = SentimentIntensityAnalyzer()

# %%
tweet_df['sentiment']=tweet_df['text'].apply(lambda x: sid.polarity_scores(x))

# %%
tweet_df.head(10)
# Out:
#     geo  \
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None
# 5  None
# 6  None
# 7  None
# 8  None
# 9  None
#
#                                                                                                                               text  \
# 0   We are flooded with requests for #Plasma. Pl come forward to donate &amp; save lives of fellow countrymen.Kindly click the li…
# 1                            #BBCYourQuestions One only needs to see media from #India to understand why #Covid is rising. Peopl…
# 2           #COVID positivity rate in🇵🇰 based on cities during the last 24 hours.Mardan:34.27%Multan:33.55%Peshawar:26.06%Bahawal…
# 3       #SOS #SOSNaviMumbai #Urgent I need ventilator for a senior citizen in Navi Mumbai please help 🙏🏼 HE'S 85 AND VERY CRITICA…
# 4                                                Remdevisir thread 😷#covid #COVIDEmergency2021 #CovidIndia #coronavirus #CovidHelp
# ...

# %%
# !pip install googlemaps

# %%
import googlemaps

# %%
url="https://maps.googleapis.com/maps/api/js?key=AIzaSyDav5nOFWUBUYKgQE4vFJ2P_yZYEtVu0gU&callback=initMap"

# %%
import requests
# !pip install config
import config

# %%
import matplotlib.pyplot as plt

xAxis=tweet_df.location
yAxis=tweet_df.value_counts()

plt.bar(xAxis,yAxis)
plt.title('title name')
plt.xlabel('xAxis name')
plt.ylabel('yAxis name')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-3e51064a0df7> in <module>
#       2
#       3 xAxis=tweet_df.location
# ----> 4 yAxis=tweet_df.value_counts()
#       5
#       6 plt.bar(xAxis,yAxis)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
tweet_df['location'].value_counts().plot(kind='bar',figsize=(15, 6));

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
# %matplotlib inline

import re
def tweetSearch(query, limit = 100, language = "en", remove = []):  
    text = " "
    for tweet in tw.Cursor(api.search, q=query, lang=language).items(limit):
        text += tweet.text.lower()
    #removed unwanted words
    text=re.sub("RT :","",text)
    text=re.sub("@[\w]*","",text)
    text=re.sub("https?://[A-Za-z0-9./]*","",text)
    text=re.sub("\n","",text)
    return text
    #Replace unwanted words with empty space

# %%
search = tweetSearch("covid")
wordcloud = WordCloud().generate(search)
plt.figure(figsize=(12,6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.showsearch = tweetSearch("covid")
